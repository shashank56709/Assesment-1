# %% [markdown]
#  **Problem - 1: Getting Started with Data Exploration - Some Warm up
# Exercises:**

# %% [markdown]
# Data Exploration and Understanding:

# %%
#Importing All Modules
import pandas as pd
import matplotlib.pyplot as plt #For Diagram
import seaborn as sns #For Diagram

# %% [markdown]
# Dataset Overview:
# 1. Load the dataset and display the first 10 rows.
# 2. Identify the number of rows and columns in the dataset.
# 3. List all the columns and their data types.

# %%
#1
data_set = '/content/drive/MyDrive/Python Sem 3 Workshop /Assesement/WHR-2024-5CS037.csv'
df = pd.read_csv(data_set)
print("The First 10 Rows are: ")
print(df.head(10))#Displays first 10 Rows
#2
print("Number of rows and columns:", df.shape)#Gives number of rows and column
#3
print("Columns and data types:\n", df.dtypes)#Shoes Data types
# Out:
# The First 10 Rows are:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.

# %%
#For Basic Statistics
mean = df['score'].mean()
median = df['score'].median()
standard_deviation = df['score'].std()
print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", standard_deviation)
#For knowing high happiest and low happiest
max_row = df.loc[df['score'].idxmax()]#For maximim value in score column
max_value = max_row['Country name']
min_row = df.loc[df['score'].idxmin()]#For minimum value in score column
min_value = df['Country name'].min()#For minimum
print("High Score:", max_value)
print("Low Score:", min_value)
# Out:
# Mean: 5.52758041958042
# Median: 5.785
# Standard Deviation: 1.1707165099442995
# High Score: Finland
# Low Score: Afghanistan

# %% [markdown]
# Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
null_values = df.isnull().sum()#Checks for missing values
print("Unique Values in Each Column:",null_values)
# Out:
# Unique Values in Each Column: Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# Happiness Category              0
# dtype: int64

# %% [markdown]
# Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
filter = df[df['score']>7.5]#include data less than 75
print("Filtered Data: ",filter[['Country name','score']])
sort_data = filter.sort_values('Log GDP per capita', ascending=False)#Sorts the filtered dataset by GDP per Capita in descending order.
print("Sorted Data: ")
print(sort_data.head(10))
# Out:
# Filtered Data:    Country name  score
# 0      Finland  7.741
# 1      Denmark  7.583
# 2      Iceland  7.525
# Sorted Data:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual Happiness Category
# 1                      0.548                1.881               high
# 2                      0.182                2.050               high
# 0                      0.546                2.082               high

# %% [markdown]
# Adding New Columns:
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
# Medium − (4 ≤ Score ≤ 6)
# High − (Score > 6)

# %%
null_values = df.isnull().sum()#Checks for missing values
print("Unique Values in Each Column:",null_values)

filter = df[df['score']>7.5]#include data less than 7.5
print("Filtered Data: ",filter)
sort_data = filter.sort_values('Log GDP per capita', ascending=False)#Sorts the filtered dataset by GDP per Capita in descending order.
print("Sorted Data: ")
sort_data.head(10)

def happiness(score):
  if score <4:
    return 'low'
  elif 4<= score <= 6:
    return 'medium'
  else:
    return 'high'
df['Happiness Category'] = df['score'].apply(happiness)
print("Data with Happiness Category: ")
print(df.head(10))
# Out:
# Unique Values in Each Column: Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64
# Filtered Data:    Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# ...

# %% [markdown]
# **2. Data Visualizations:
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.
# • Plot a histogram for the Score column to show its distribution and also interpret.
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
#Diagram
# 1. Bar Plot: Top 10 happiest countries by Score
ten_happiest = df.nlargest(10, 'score')
plt.figure(figsize=(10, 6))
sns.barplot(x='score', y='Country name', data=ten_happiest, palette='colorblind')
plt.title('Top 10 Happiest Countries by Score')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()

#2. Line Plot: Top 10 unhappiest countries by Score
ten_unhappiest = df.nsmallest(10, 'score')
plt.figure(figsize=(10, 6))
sns.lineplot(x='score', y='Country name', data=ten_unhappiest, marker='o',color='black',linestyle='-',palette='colorblind')
plt.title('Top 10 Unhappiest Countries by Score')
plt.xlabel('Happiness Score')
plt.ylabel('Country');
plt.show()

#3. Histogram: Distribution of the Score column
plt.figure(figsize=(10, 6))
sns.histplot(df['score'], bins=20, kde=True, color='orange')
plt.title('Distribution of Happiness Scores')
plt.xlabel('Happiness Score')
plt.ylabel('Frequency')
plt.show()

#4. Scatter Plot: GDP per Capita vs Happiness Score
plt.figure(figsize=(10, 6))
sns.scatterplot(x='score', y='Log GDP per capita', data=df, palette='colorblind')
plt.title('Happiness vs. Log GDP per Capita')
plt.title('GDP per Capita vs Happiness Score')
plt.xlabel('GDP per Capita')
plt.ylabel('Happiness Score')
plt.show()
# Out:
# <ipython-input-17-8f696939fc70>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='score', y='Country name', data=ten_happiest, palette='colorblind')
# <ipython-input-17-8f696939fc70>:14: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x='score', y='Country name', data=ten_unhappiest, marker='o',color='black',linestyle='-',palette='colorblind')
# <ipython-input-17-8f696939fc70>:30: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='score', y='Log GDP per capita', data=df, palette='colorblind')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Problem - 2 - Some Advance Data Exploration Task:**
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
# Steps:
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
#
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
data_set = '/content/drive/MyDrive/Python Sem 3 Workshop /Assesement/WHR-2024-5CS037.csv'
df = pd.read_csv(data_set)
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Srilanka"]
south_asia = df.loc[df['Country name'].isin(south_asian_countries)]#Filter the dataset for South Asian countries
print(south_asia.head(10))
south_asia.to_csv('new_happiness_CV')#Sending to new CV
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
#      Perceptions of corruption  Dystopia + residual
# 92                       0.115                1.783
# 107                      0.074                1.907
# ...

# %% [markdown]
# Task - 2 - Composite Score Ranking:
# Tasks:
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
#
# + 0.30 × Healthy Life Expectancy
# 2. Rank the South Asian countries based on the Composite Score in descending order.
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
#2 Creating Column
south_asia['Composite Score'] = (0.40*south_asia['Log GDP per capita']+0.30*south_asia['Social support']+ 0.30*south_asia['Healthy life expectancy'])
south_asia_sorted = south_asia.sort_values(by='Composite Score', ascending=False)
top_5 = south_asia_sorted.head(5)#Displaying Descending Order

#Visualizing
plt.figure(figsize=(8, 5))
sns.barplot(x='Composite Score', y='Country name', data=top_5, palette='colorblind')
plt.title('Top 5 South Asian Countries by Composite Score')
plt.xlabel('Composite Score')
plt.ylabel('Country')
plt.show()

plt.figure(figsize=(8, 5))
sns.scatterplot(x='score', y='Composite Score', data=south_asia, color='purple', style='Country name')
plt.title('Happiness Score vs Composite Score')
plt.xlabel('Happiness Score')
plt.ylabel('Composite Score')
plt.show()
# Out:
# <ipython-input-20-6089e0aa30dc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asia['Composite Score'] = (0.40*south_asia['Log GDP per capita']+0.30*south_asia['Social support']+ 0.30*south_asia['Healthy life expectancy'])
# <ipython-input-20-6089e0aa30dc>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Composite Score', y='Country name', data=top_5, palette='colorblind')

# %% [markdown]
# As seen on the diagram the points are diagnoal to each other so they are in correlation. The distance away from the diagonal indicate countries with a composite different from the orginal score. One of the point is significantly lower than top ones which can be one ofthe outliers

# %% [markdown]
# Task - 3 - Outlier Detection:
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
#To find Ouliers we will be using IQR whereFinding Quartle third(75%) and first(25%)
Q1_score = south_asia['score'].quantile(0.25)
Q3_score = south_asia['score'].quantile(0.75)
IQR_score = Q3_score - Q1_score

lower_bound_score = Q1_score - 1.5 * IQR_score
upper_bound_score = Q3_score + 1.5 * IQR_score

Q1_gdp = south_asia['Log GDP per capita'].quantile(0.25)
Q3_gdp = south_asia['Log GDP per capita'].quantile(0.75)
IQR_gdp = Q3_gdp - Q1_gdp

lower_bound_gdp = Q1_gdp - 1.5 * IQR_gdp
upper_bound_gdp = Q3_gdp + 1.5 * IQR_gdp

outliers = south_asia[
    (south_asia['score'] < lower_bound_score) | (south_asia['score'] > upper_bound_score) |
    (south_asia['Log GDP per capita'] < lower_bound_gdp) | (south_asia['Log GDP per capita'] > upper_bound_gdp)
]

print("Outlier Countries:")
print(outliers[['Country name', 'score', 'Log GDP per capita']])

plt.figure(figsize=(8,6))
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia, color='blue')
sns.scatterplot(x='Log GDP per capita', y='score', data=outliers, label='Outliers', color='red', marker='x')
plt.title('Scatter Plot of Happiness Score vs Log GDP per Capita')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.show()
# Out:
# Outlier Countries:
#     Country name  score  Log GDP per capita
# 142  Afghanistan  1.721               0.628

# %% [markdown]
# Outliers appears in color red which indicate ower GDP per Capita and Score. The outliers may indicate lower performing countries and higher scores with high perfomring countries more on progress.

# %% [markdown]
# Task - 4 - Exploring Trends Across Metrics:
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.
# 2. Create scatter plots with trendlines for these metrics against the Score.
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
freedom = south_asia['Freedom to make life choices'].corr(south_asia['score'])
genoricity = south_asia['Generosity'].corr(south_asia['score'])
print("Correlation between 'Freedom to make life choices' and 'score':", freedom)
print("Correlation between 'Generosity' and 'score':", genoricity)
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Freedom to make life choices', y='score', data=south_asia, color='blue')
plt.title('Scatter Plot of Happiness Score vs Freedom to make life choices')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Happiness Score')
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Generosity', y='score', data=south_asia, color='green')
plt.title('Scatter Plot of Happiness Score vs Generosity')
plt.xlabel('Generosity')
plt.ylabel('Happiness Score')
plt.show()
# Out:
# Correlation between 'Freedom to make life choices' and 'score': 0.801497903141921
# Correlation between 'Generosity' and 'score': 0.8773326267276359

# %% [markdown]
# Strongest Relation are those whiich has the highest correlation valueWeakest Relation are those which has lowest coorelation value.

# %% [markdown]
# Task - 5 - Gap Analysis:
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
south_asia['GDP-Score Gap'] =south_asia['Log GDP per capita']-south_asia['score']
print(south_asia.head(10))
ascending_order = south_asia.sort_values(by='GDP-Score Gap', ascending=True)
top_5 = ascending_order[['Country name','GDP-Score Gap']].head(3)
descending_order = south_asia.sort_values(by='GDP-Score Gap', ascending=False)
bottom_5 = descending_order[['Country name','GDP-Score Gap']].head(3)
print('Top 5:',top_5)
print('Bottom 5:',bottom_5)

plt.figure(figsize=(10, 6))
sns.barplot(x='GDP-Score Gap', y='Country name', data=top_5, palette='viridis')
plt.title('Top 5 South Asian Countries by GDP-Score Gap')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country')
plt.show()

plt.figure(figsize=(10,6))
sns.barplot(x='GDP-Score Gap', y='Country name', data=bottom_5, palette='viridis')
plt.title('Bottom 5 South Asian Countries by GDP-Score Gap')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country')
plt.show()
# Out:
# <ipython-input-28-b215831ee699>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asia['GDP-Score Gap'] =south_asia['Log GDP per capita']-south_asia['score']
# <ipython-input-28-b215831ee699>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='GDP-Score Gap', y='Country name', data=top_5, palette='viridis')
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# ...

# %% [markdown]
# Positive gaps are due to countries where GDP is high but happiness is low and vice versa for negative gaps

# %% [markdown]
# **Problem - 3 - Comparative Analysis:**
# Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:
# Tasks:
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
# "United Arab Emirates", "Yemen"]
#
# Complete the following task:

# %%
middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan","Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria","United Arab Emirates", "Yemen"]
middle_east = df.loc[df['Country name'].isin(middle_east_countries)]
print(middle_east.head(10))
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %% [markdown]
# **1. Descriptive Statistics:**
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
#
# • Which region has higher happiness Scores on average?

# %%
#Calculating Statistics
std_middle_east = middle_east['score'].std()
print("Standard Deviation of Middle East Countries:", std_middle_east)
std_south_asia = south_asia['score'].std()
print("Standard Deviation of South Asian Countries:", std_south_asia)
mean_middle_east = middle_east['score'].mean()
print("Mean of Middle East Countries:", mean_middle_east)
mean_south_asia = south_asia['score'].mean()
print("Mean of South Asian Countries:", mean_south_asia)
# Out:
# Standard Deviation of Middle East Countries: 1.5662011684327144
# Standard Deviation of South Asian Countries: 1.3160025455902433
# Mean of Middle East Countries: 5.412100000000001
# Mean of South Asian Countries: 3.8952000000000004

# %% [markdown]
# Middle East countries has highest average

# %% [markdown]
# **2. Top and Bottom Performers:**
# • Identify the top 3 and bottom 3 countries in each region based on the score.
#
# • Plot bar charts comparing these charts.

# %%
top3_middle_east = middle_east.nlargest(3, 'score')
print("Top 3 Middle East Countries by Score:")
print(top3_middle_east)
bottom3_middle_East = middle_east.nsmallest(3, 'score')
print("Bottom 3 Middle East Countries by Score:")
print(bottom3_middle_East)
top3_south_asia = south_asia.nlargest(3, 'score')
print("Top 3 South Asian Countries by Score:")
print(top3_south_asia)
bottom3_south_asia = south_asia.nsmallest(3, 'score')
print("Bottom 3 Middle East Countries by Score:")
print(bottom3_south_asia)

#For Top 3  middle east
plt.figure(figsize=(10,6))
sns.barplot(x='score', y='Country name', data=top3_middle_east, palette='viridis')
plt.title('Top 3 Middle East Countries by Score')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()

#For Bottom 3 middle east
plt.figure(figsize=(10,6))
sns.barplot(x='score', y='Country name', data=bottom3_middle_East, palette='viridis')
plt.title('Bottom 3 Middle East Countries by Score')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()

#For Top 3 south asia
plt.figure(figsize=(10,6))
sns.barplot(x='score', y='Country name', data=top3_south_asia, palette='viridis')
plt.title('Top 3 South Asia Countries by Score')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()

#For Bottom 3 South Asia
plt.figure(figsize=(10,6))
sns.barplot(x='score', y='Country name', data=bottom3_south_asia, palette='viridis')
plt.title('Bottom 3 South Asia Countries by Score')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()
# Out:
# Top 3 Middle East Countries by Score:
#             Country name  score  Log GDP per capita  Social support  \
# 4                 Israel  7.341               1.803           1.513
# 12                Kuwait  6.951               1.845           1.364
# 21  United Arab Emirates  6.733               1.983           1.164
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                     0.740                         0.641       0.153
# 12                    0.661                         0.827       0.200
# 21                    0.563                         0.815       0.209
#
#     Perceptions of corruption  Dystopia + residual
# 4                       0.193                2.298
# 12                      0.172                1.884
# 21                      0.258                1.741
# Bottom 3 Middle East Countries by Score:
#     Country name  score  Log GDP per capita  Social support  \
# 141      Lebanon  2.707               1.377           0.577
# ...

# %% [markdown]
# 3. Metric Comparisons:
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy between the regions using grouped bar charts.
#
# • Which metrics show the largest disparity between the two regions?

# %%
metric = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
south_asia_mean = south_asia[metric].mean()
middle_east_mean = middle_east[metric].mean()

metrics_comparison = pd.DataFrame({
    'South Asia': south_asia_mean,
    'Middle East': middle_east_mean
})
#Diagram
metrics_comparison.plot(kind='bar', figsize=(6, 4), color=['blue', 'green'])
plt.title("Metric Comparisons: South Asia vs Middle East")
plt.ylabel("Average Values")
plt.xlabel("Metrics")
plt.xticks(rotation=0)
plt.legend(title="Region")
plt.tight_layout()
plt.show()

disparities = south_asia_mean - middle_east_mean
largest_disparities = disparities.nlargest(3)
print("Largest Disparity",largest_disparities)
# Out:
# Largest Disparity Healthy life expectancy   -0.166911
# Log GDP per capita        -0.506333
# Social support            -0.654378
# dtype: float64

# %% [markdown]
# **4. Happiness Disparity:**
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
# • Which region has greater variability in happiness?

# %%
#4
south_asia_range = south_asia[metric].max() - south_asia[metric].min()
middle_east_range = middle_east[metric].max() - middle_east[metric].min()
cv_south_asia = std_south_asia / south_asia_mean #Co-Efficient Variation
cv_middle_east = std_middle_east / middle_east_mean
print("Coefficient of Variation for South Asian Countries:")
print(cv_south_asia)
print("Coefficient of Variation for Middle East Countries:")
print(cv_middle_east)
#South Asia
# Out:
# Coefficient of Variation for South Asian Countries:
# Log GDP per capita         1.329296
# Social support             2.640455
# Healthy life expectancy    3.398767
# dtype: float64
# Coefficient of Variation for Middle East Countries:
# Log GDP per capita         1.046693
# Social support             1.358632
# Healthy life expectancy    2.826511
# dtype: float64

# %% [markdown]
# **5. Correlation Analysis:**
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
# • Create scatter plots to visualize and interpret the relationships.

# %%
metrics = ['Freedom to make life choices', 'Generosity']
south_asia_correlation = south_asia[metrics].corr()
middle_east_correlation = middle_east[metrics].corr()
print("Correlation Matrix for South Asian Countries:")
print(south_asia_correlation)
print("Correlation Matrix for Middle East Countries:")
print(middle_east_correlation)

# Scatter plots for South Asia
for metric in metrics:
    sns.regplot(x=metric, y='score', data=south_asia, label=metric, color='green')
    plt.title(f"South Asia: {metric} vs Happiness Score")
    plt.show()

# Scatter plots for Middle East
for metric in metrics:
    sns.regplot(x=metric, y='score', data=middle_east, label=metric, color='blue')
    plt.title(f"Middle East: {metric} vs Happiness Score")
    plt.show()
# Out:
# Correlation Matrix for South Asian Countries:
#                               Freedom to make life choices  Generosity
# Freedom to make life choices                       1.00000     0.74066
# Generosity                                         0.74066     1.00000
# Correlation Matrix for Middle East Countries:
#                               Freedom to make life choices  Generosity
# Freedom to make life choices                      1.000000    0.388854
# Generosity                                        0.388854    1.000000

# %% [markdown]
# **6. Outlier Detection:**
# • Identify outlier countries in both regions based on Score and GDP per Capita.
# • Plot these outliers and discuss their implications.

# %%
def detect_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] < lower_bound) | (df[column] > upper_bound)]

south_asia_outliers_score = detect_outliers(south_asia, 'score')
south_asia_outliers_gdp = detect_outliers(south_asia, 'Log GDP per capita')

middle_east_outliers_score = detect_outliers(middle_east, 'score')
middle_east_outliers_gdp = detect_outliers(middle_east, 'Log GDP per capita')

plt.figure(figsize=(6, 4))

plt.subplot(1, 2, 1)
plt.scatter(south_asia['Log GDP per capita'], south_asia['score'], color='blue', label='Non-Outliers')
plt.scatter(south_asia_outliers_score['Log GDP per capita'], south_asia_outliers_score['score'], color='red', label='Outliers (Score)')
plt.scatter(south_asia_outliers_gdp['Log GDP per capita'], south_asia_outliers_gdp['score'], color='green', label='Outliers (GDP per Capita)')
plt.title("South Asia: Outliers in GDP per Capita and Score")
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(middle_east['Log GDP per capita'], middle_east['score'], color='blue', label='Non-Outliers')
plt.scatter(middle_east_outliers_score['Log GDP per capita'], middle_east_outliers_score['score'], color='red', label='Outliers (Score)')
plt.scatter(middle_east_outliers_gdp['Log GDP per capita'], middle_east_outliers_gdp['score'], color='green', label='Outliers (GDP per Capita)')
plt.title("Middle East: Outliers in GDP per Capita and Score")
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

print("South Asia Outliers based on Score and GDP per Capita:")
print(south_asia_outliers_score[['Country name', 'score', 'Log GDP per capita']])
print(south_asia_outliers_gdp[['Country name', 'score', 'Log GDP per capita']])

print("\nMiddle East Outliers based on Score and GDP per Capita:")
print(middle_east_outliers_score[['Country name', 'score', 'Log GDP per capita']])
print(middle_east_outliers_gdp[['Country name', 'score', 'Log GDP per capita']])
# Out:
# South Asia Outliers based on Score and GDP per Capita:
#     Country name  score  Log GDP per capita
# 142  Afghanistan  1.721               0.628
#     Country name  score  Log GDP per capita
# 142  Afghanistan  1.721               0.628
#
# Middle East Outliers based on Score and GDP per Capita:
# Empty DataFrame
# Columns: [Country name, score, Log GDP per capita]
# Index: []
# Empty DataFrame
# Columns: [Country name, score, Log GDP per capita]
# Index: []

# %% [markdown]
# **7. Visualization:**
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
south_asia['Region'] = 'South Asia'
middle_east['Region'] = 'Middle East'

combined_df = pd.concat([south_asia[['score', 'Region']], middle_east[['score', 'Region']]])

plt.figure(figsize=(6, 4))
sns.boxplot(x='Region', y='score', data=combined_df, palette='Set2')

plt.title("Distribution of Happiness Score: South Asia vs Middle East")
plt.xlabel('Region')
plt.ylabel('Happiness Score')

plt.show()
# Out:
# <ipython-input-48-6e4afb5518e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asia['Region'] = 'South Asia'
# <ipython-input-48-6e4afb5518e1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   middle_east['Region'] = 'Middle East'
# <ipython-input-48-6e4afb5518e1>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
df
# Out:
#          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.695                         0.859       0.142
# ...
